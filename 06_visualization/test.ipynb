# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_file = r"\\192.168.205.122\Contenedores\5-Resultados\P2_CONTENEDORES\SPL\Graphics_RASPBERRY\P2_CONTENEDORES_peaks_filtered.csv"
df = pd.read_csv(csv_file)
df
# Out:
#      id_micro                                           Filename  \
# 0       RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 1       RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 2       RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 3       RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 4       RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# ...       ...                                                ...
# 2894    RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 2895    RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 2896    RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 2897    RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 2898    RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
#
#                 Timestamp  Unixtimestamp     LA     LC     LZ  LAmax  LAmin  \
# 0     2025-04-01 13:10:04     1743505804  79.96  87.93  91.37  84.25  67.63
# ...

# %%
# half_df = len(df) // 2
# print(f"Half of the DataFrame length: {half_df}")


# df = df[:half_df]
# df

# %%
#plot data with matplotlib
plt.figure(figsize=(20, 6))
plt.plot(df['Timestamp'], df['LA_corrected'], label='LA_corrected', color='blue', linewidth=2)
plt.xlabel('Time')
plt.ylabel('LA_corrected Values')
plt.title('LA_corrected and Filtered Values Over Time')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
csv_file = r"\\192.168.205.122\Contenedores\5-Resultados\P2_CONTENEDORES\SPL\Graphics_RASPBERRY\P2_CONTENEDORES_peaks.csv"
df = pd.read_csv(csv_file)
df
# Out:
#      id_micro                                           Filename  \
# 0       RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 1       RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 2       RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 3       RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 4       RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# ...       ...                                                ...
# 4923    RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 4924    RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 4925    RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 4926    RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
# 4927    RPI_2  \\192.168.205.122\Contenedores\P2_CONTENEDORES...
#
#                 Timestamp  Unixtimestamp     LA     LC     LZ  LAmax  LAmin  \
# 0     2025-04-01 13:03:13     1743505393  78.22  85.04  87.51  85.55  68.02
# ...

# %%
# half_df = len(df) // 2
# print(f"Half of the DataFrame length: {half_df}")


# df = df[:half_df]
# df

# %%
#plot data with matplotlib
plt.figure(figsize=(20, 6))
plt.plot(df['Timestamp'], df['LA_corrected'], label='LA_corrected', color='blue', linewidth=2)
plt.xlabel('Time')
plt.ylabel('LA_corrected Values')
plt.title('LA_corrected and Filtered Values Over Time')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
